# %%
from pos.models import ArretOperation, Article, Avarie, Categorie, Entree, Sortie, Vente

# %%
from pos.views import quantite_en_stock, catalogue_et_stock

# %%
import os

# %%
os.environ["DJANGO_ALLOW_ASYNC_UNSAFE"] = "true"

# %%
Article.objects.all()
# Out:
# <QuerySet [<Article: NIDO>, <Article: Fanta>, <Article: Day by day men>, <Article: aa>]>

# %%
from pos.views import quantite_en_stock

# %%
quantite_en_stock(Article.objects.get(nom_article='Fanta'))
# Out:
# 0

# %%
quantite_en_stock(Article.objects.get(nom_article='aa'))
# Out:
# 6

# %%
catalogue_et_stock()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-95c71206106d> in <module>
# ----> 1 catalogue_et_stock()
#
# ~/Documents/labo/django/ALPOS/pos/views.py in catalogue_et_stock()
#      58
#      59     for article in liste_articles_en_catalogue:
# ---> 60         print(article.nom_article)
#      61
#      62
#
# AttributeError: 'dict' object has no attribute 'nom_article'
